# %%
from demisfasc_functions import *

import pandas as pd
import numpy as np
from itertools import zip_longest
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm
# %matplotlib inline

# %%
applyAll('e1745','48h')
applyAll('eq1','48h')
applyAll('hmnIs23 M153L2','48h')
applyAll('ky146','48h')
applyAll('ky146','24h')
applyAll('ky146','72h')
applyAll('ky146mu256','48h')
applyAll('m86sa204','48h')
applyAll('M132L4','48h')
applyAll('M144L2 N2','48h')
applyAll('M157L1','48h')
applyAll('mu256','48h')
applyAll('mu256','24h')
applyAll('mu256','72h')
applyAll('nj53', '48h')
applyAll('ok244','48h')
applyAll('ok711', '48h')
applyAll('osm6nlsrfp','48h')
applyAll('ptp3SAX','48h')
applyAll('rh310', '24h')
applyAll('rh310','48h')
applyAll('u74','48h')
applyAll('wy686','48h')
applyAll('WT','48h')
applyAll('WT','24h')
applyAll('WT','72h')



# broken but don't need
# applyAll('rh310 control','48h')
# applyAll('ok1489','48h')
# Out:
# ['SADA csv files binned/e1745/48h 60x/71_101716hmnIs17hmnIs23e1745-14_R3D_D3D_outputis defasciculated']
# ['SADA csv files binned/e1745/48h 60x/75_101716hmnIs17hmnIs23e1745-07_R3D_D3D_outputis defasciculated']
# ['SADA csv files binned/e1745/48h 60x/83_101716hmnIs17hmnIs23e1745-11_R3D_D3D_outputis defasciculated']
# ['SADA csv files binned/eq1/48h 60x/67_111116hmnIs17hmnIs23eq1-08_R3D_D3D_outputis defasciculated']
# ['SADA csv files binned/eq1/48h 60x/69_111116hmnIs17hmnIs23eq1-02_R3D_D3D_outputis defasciculated']
# ['SADA csv files binned/eq1/48h 60x/72_111116hmnIs17hmnIs23eq1-01_R3D_D3D_outputis defasciculated']
# ['SADA csv files binned/eq1/48h 60x/74_111116hmnIs17hmnIs23eq1-19_R3D_D3D_outputis defasciculated']
# ['SADA csv files binned/hmnIs23 M153L2/48h 60x/73_160728hmnIs23M153L2-02_R3D_D3D_outputis defasciculated']
# ['SADA csv files binned/ky146/48h 60X 151031/51_103115ky146hmnIs17hmnIs23t48h-08_R3D_D3D_outputis defasciculated']
# ['SADA csv files binned/ky146/24h 60x 151030/47_103015ky146hmnIs17hmnIs23t24h-19_R3D_D3D_outputis defasciculated']
# ['SADA csv files binned/ky146/72h 60x 151101/74_110115ky146hmnIs17hmnIs23t72h-12_R3D_D3D_outputis defasciculated']
# ['SADA csv files binned/ky146/72h 60x 151101/74_110115ky146hmnIs17hmnIs23t72h-07_R3D_D3D_outputis defasciculated']
# ['SADA csv files binned/ky146mu256/48h 60x/56_011216ky146mu256hmnIs23hmnIs17a-03_R3D_D3D_outputis defasciculated']
# ['SADA csv files binned/ky146mu256/48h 60x/60_011216ky146mu256hmnIs17hmnIs23-13_R3D_D3D_outputis defasciculated']
# ['SADA csv files binned/ky146mu256/48h 60x/61_011216ky146mu256hmnIs17hmnIs23-15_R3D_D3D_outputis defasciculated']
# ['SADA csv files binned/ky146mu256/48h 60x/64_011216ky146mu256hmnIs17hmnIs23-05_R3D_D3D_outputis defasciculated']
# ['SADA csv files binned/ky146mu256/48h 60x/68_011216ky146mu256hmnIs17hmnIs23-18_R3D_D3D_outputis defasciculated']
# ['SADA csv files binned/ky146mu256/48h 60x/68_011216ky146mu256hmnIs17hmnIs23-19_R3D_D3D_outputis defasciculated']
# ['SADA csv files binned/ky146mu256/48h 60x/69_012916ky146mu256hmnIs17hmnIs23-13_R3D_D3D_outputis defasciculated']
# ['SADA csv files binned/ky146mu256/48h 60x/69_012916ky146mu256hmnIs17hmnIs23-16_R3D_D3D_outputis defasciculated']
# ['SADA csv files binned/ky146mu256/48h 60x/70_011216ky146mu256hmnIs17hmnIs23-16_R3D_D3D_outputis defasciculated']
# ['SADA csv files binned/ky146mu256/48h 60x/72_012916ky146mu256hmnIs17hmnIs23-10_R3D_D3D_outputis defasciculated']
# ['SADA csv files binned/m86sa204/48h 60x/78_160507daf12daf19hmnIs17hmnIs23-03_R3D_D3D_outputis defasciculated']
# ['SADA csv files binned/M132L4/48h 60x/75_030816hmnIs17hmnIs23M132L4-09_R3D_outputis defasciculated']
# ['SADA csv files binned/M132L4/48h 60x/81_032316hmnIs17hmnIs23M132L4-02_R3D_D3D_outputis defasciculated']
# 051718-CHB2525-3 changed channel order
# 051618b-CHB2525-1 changed channel order
# ['SADA csv files binned/M157L1/48h 60x/69_051618b-CHB2525-3_R3D_D3D_outputis defasciculated']
# 051718-CHB2525-2 changed channel order
# 051618-CHB2525-1 changed channel order
# ['SADA csv files binned/M157L1/48h 60x/85_092716hmnIs17hmnIs23M157L1-03_R3D_D3D_outputis defasciculated']
# 051618b-CHB2525-4 changed channel order
# 051618c-CHB2525-2 changed channel order
# 051618-CHB2525-5 changed channel order
# ['SADA csv files binned/mu256/48h 60x 151001/56_100115mu256hmnIs17hmnIs23t48h-12_R3D_D3D_outputis defasciculated']
# ['SADA csv files binned/mu256/48h 60x 151001/57_100115mu256hmnIs17hmnIs23t48h-07_R3D_D3D_outputis defasciculated']
# ['SADA csv files binned/mu256/24h 60x 150930/45_093015mu256hmnIs17hmnIs23t24h-06_R3D_D3D_outputis defasciculated']
# ['SADA csv files binned/mu256/72h 60x 151002/68_100215mu256hmnIs17hmnIs23t72h-23_R3D_D3D_outputis defasciculated']
# ['SADA csv files binned/mu256/72h 60x 151002/76_100215mu256hmnIs17hmnIs23t72h-17_R3D_D3D_outputis defasciculated']
# ['SADA csv files binned/nj53/48h 60x/71_051618-nj53-19_R3D_D3D_outputis defasciculated']
# 051618-nj53-18 changed channel order
# ['SADA csv files binned/nj53/48h 60x/75_051618-nj53-15_R3D_D3D_outputis defasciculated']
# 051618-nj53-7 changed channel order
# ['SADA csv files binned/nj53/48h 60x/68_051618-nj53-16_R3D_D3D_outputis defasciculated']
# ['SADA csv files binned/nj53/48h 60x/75_051618-nj53-1_R3D_D3D_outputis defasciculated']
# 051618-nj53-20 changed channel order
# ['SADA csv files binned/nj53/48h 60x/74_051618-nj53-14_R3D_D3D_outputis defasciculated']
# 051618-nj53-6 changed channel order
# ['SADA csv files binned/nj53/48h 60x/74_051618-nj53-9_R3D_D3D_outputis defasciculated']
# 051618-nj53-21 changed channel order
# 051618-nj53-3 changed channel order
# 051618-nj53-11 changed channel order
# 051618-nj53-8 changed channel order
# 051618-nj53-2 changed channel order
# 051618-nj53-13 changed channel order
# 051618-nj53-12 changed channel order
# ['SADA csv files binned/nj53/48h 60x/68_051618-nj53-22_R3D_D3D_outputis defasciculated']
# ['SADA csv files binned/nj53/48h 60x/62_060418-nj53-2b01_R3D_D3D_outputis defasciculated']
# ['SADA csv files binned/nj53/48h 60x/70_060418-nj53-3_R3D_D3D_outputis defasciculated']
# 060418-nj53-6 changed channel order
# ['SADA csv files binned/nj53/48h 60x/72_060418-nj53-5_R3D_D3D_outputis defasciculated']
# 060418b-nj53-2 changed channel order
# 060418-nj53-11 changed channel order
# 060418b-nj53-7 changed channel order
# 060418b-nj53-8 changed channel order
# 052118-osm6nlsrfp-7 changed channel order
# ['SADA csv files binned/osm6nlsrfp/48h 60x/71_052118-osm6nlsrfp-14_R3D_D3D_outputis defasciculated']
# ['SADA csv files binned/osm6nlsrfp/48h 60x/71_052118-osm6nlsrfp-19_R3D_D3D_outputis defasciculated']
# 052118-osm6nlsrfp-21 changed channel order
# ['SADA csv files binned/osm6nlsrfp/48h 60x/74_052118-osm6nlsrfp-5_R3D_D3D_outputis defasciculated']
# 052118-osm6nlsrfp-11 changed channel order
# ['SADA csv files binned/osm6nlsrfp/48h 60x/73_052118-osm6nlsrfp-24_R3D_D3D_outputis defasciculated']
# 052118-osm6nlsrfp-29 changed channel order
# 052118-osm6nlsrfp-1 changed channel order
# 052118-osm6nlsrfp-17 changed channel order
# 052118-osm6nlsrfp-10 changed channel order
# 052118-osm6nlsrfp-28 changed channel order
# 052118-osm6nlsrfp-26 changed channel order
# 052118-osm6nlsrfp-18 changed channel order
# ['SADA csv files binned/osm6nlsrfp/48h 60x/75_052118-osm6nlsrfp-30_R3D_D3D_outputis defasciculated']
# 052118-osm6nlsrfp-4 changed channel order
# 052118-osm6nlsrfp-20 changed channel order
# 052118-osm6nlsrfp-16 changed channel order
# 052118-osm6nlsrfp-6 changed channel order
# 052118-osm6nlsrfp-13 changed channel order
# 051718-ptpSAX-10 changed channel order
# 052118-ptpSAX-4 changed channel order
# 051718-ptpSAX-4 changed channel order
# 052118-ptpSAX-5 changed channel order
# 052318-ptpSAX-3b01 changed channel order
# ['SADA csv files binned/ptp3SAX/48h 60x/72_051718-ptpSAX-7b01_R3D_D3D_outputis defasciculated']
# 051718-ptpSAX-9 changed channel order
# 052318-ptpSAX-8 changed channel order
# 051718-ptpSAX-6b01 changed channel order
# 051718-ptpSAX-5 changed channel order
# 052318-ptpSAX-1 changed channel order
# 052118-ptpSAX-1b01 changed channel order
# 052118-ptpSAX-7 changed channel order
# 051718-ptpSAX-3 changed channel order
# 051718-ptpSAX-8 changed channel order
# 052318-ptpSAX-9 changed channel order
# 051718-ptpSAX-2 changed channel order
# ['SADA csv files binned/rh310/24h 60x/54_090917rh310hmnIs17hmnIs23_24h-21_R3D_D3D_outputis defasciculated']
# ['SADA csv files binned/rh310/24h 60x/59_090917rh310hmnIs17hmnIs23_24h-11_R3D_D3D_outputis defasciculated']
# ['SADA csv files binned/rh310/24h 60x/61_090917rh310hmnIs17hmnIs23_24h-17_R3D_D3D_outputis defasciculated']
# ['SADA csv files binned/rh310/48h 60x/69_051317rh310hmnIs17M161-02_R3D_D3D_outputis defasciculated']
# ['SADA csv files binned/rh310/48h 60x/72_051217rh310hmnIs17M161-02_R3D_D3D_outputis defasciculated']
# ['SADA csv files binned/rh310/48h 60x/76_051217rh310hmnIs17M161-09_R3D_D3D_outputis defasciculated']
# ['SADA csv files binned/rh310/48h 60x/77_051217rh310hmnIs17M161-10_R3D_D3D_outputis defasciculated']
# ['SADA csv files binned/rh310/48h 60x/80_051517rh310hmnIs17M161-10_R3D_D3D_outputis defasciculated']
# 072015M68L14M88L63t48h-20 changed channel order
# 072015M68L14M88L63t48h-03 changed channel order
# 072015M68L14M88L63t48h-13 changed channel order
# 072015M68L14M88L63t48h-08 changed channel order
# 072015M68L14M88L63t48h-16 changed channel order
# 072015M68L14M88L63t48h-18 changed channel order
# 072015M68L14M88L63t48h-19 changed channel order
# 072015M68L14M88L63t48h-21 changed channel order
# 072015M68L14M88L63t48h-15 changed channel order
# 072015M68L14M88L63t48h-09 changed channel order
# 072015M68L14M88L63t48h-12 changed channel order
# 072015M68L14M88L63t48h-05 changed channel order
# 072015M68L14M88L63t48h-14 changed channel order
# 072015M68L14M88L63t48h-01 changed channel order
# 072015M68L14M88L63t48h-04 changed channel order
# 072015M68L14M88L63t48h-07 changed channel order
# 072015M68L14M88L63t48h-10 changed channel order
# 072315M68L14M88L63t24h-03 changed channel order
# 072315M68L14M88L63t24h-10 changed channel order
# 072315M68L14M88L63t24h-13 changed channel order
# 072315M68L14M88L63t24h-26 changed channel order
# 072315M68L14M88L63t24h-08 changed channel order
# 072315M68L14M88L63t24h-11 changed channel order
# 072315M68L14M88L63t24h-19 changed channel order
# 072315M68L14M88L63t24h-20 changed channel order
# 072315M68L14M88L63t24h-21 changed channel order
# 072315M68L14M88L63t24h-23 changed channel order
# 072315M68L14M88L63t24h-25 changed channel order
# 072315M68L14M88L63t24h-27 changed channel order
# 072315M68L14M88L63t24h-15 changed channel order
# 072315M68L14M88L63t24h-16 changed channel order
# 072315M68L14M88L63t24h-22 changed channel order
# 072315M68L14M88L63t24h-06 changed channel order
# 072315M68L14M88L63t24h-12 changed channel order
# 072115M68L14M88L63t72h-21 changed channel order
# 072115M68L14M88L63t72h-25 changed channel order
# 072115M68L14M88L63t72h-28 changed channel order
# 072115M68L14M88L63t72h-15 changed channel order
# 072115M68L14M88L63t72h-06 changed channel order
# 072115M68L14M88L63t72h-14 changed channel order
# 072115M68L14M88L63t72h-11 changed channel order
# 072115M68L14M88L63t72h-13 changed channel order
# 072115M68L14M88L63t72h-22 changed channel order
# 072115M68L14M88L63t72h-04 changed channel order
# 072115M68L14M88L63t72h-23 changed channel order
# 072115M68L14M88L63t72h-27 changed channel order
# 072115M68L14M88L63t72h-17 changed channel order
# 072115M68L14M88L63t72h-07 changed channel order
# 072115M68L14M88L63t72h-20 changed channel order
# 072115M68L14M88L63t72h-18 changed channel order
# 072115M68L14M88L63t72h-19 changed channel order
# 072115M68L14M88L63t72h-16 changed channel order
# 072115M68L14M88L63t72h-05 changed channel order
# 072115M68L14M88L63t72h-08 changed channel order

# %% [raw]
# # maximum pairwise distance csv + plot + middledendrite csv
# def maxpairwiseAndMiddleDendrite(genotype, timepoint):
#     max_pairwise_df = pd.DataFrame()
#     middle_dendrite_df = pd.DataFrame()
#
#     all_animals = pd.read_csv('180531_defasc_classifier_ver2.csv',
#                               index_col=['Unnamed: 0'])\
#                     [['genotype','timepoint','id','test5']]
#
#     for animal in all_animals[(all_animals.genotype==genotype) & (all_animals.timepoint==timepoint)].id.values:
#         print (animal)
#         single_animal_df = pd.read_csv('./' + animal + '.csv')
#
#
#         # cut off pixels toward cell body for all pairwise distances
#         normalized_pairwise_distances = normalization(single_animal_df.RG_dist,
#                                                       single_animal_df.BR_dist,
#                                                       single_animal_df.GB_dist,
#                                                       animal, timepoint)
#         binned_distances_transposed = pd.DataFrame(binned_dist(normalized_pairwise_distances[0],
#                                                    normalized_pairwise_distances[1],
#                                                    normalized_pairwise_distances[2],
#                                                    100),
#                                                    columns=['RG_binned', 'BR_binned', 'GB_binned'])
#
#         binned_distances_transposed['max_pairwise'] = binned_distances_transposed.max(axis=1)
#
#         # get max pairwise distances
#         max_pairwise_df[animal.split('/')[-1]] = binned_distances_transposed['max_pairwise']
#
#         # get middle dendrite population.csv only if it's fasciculated
#         if all_animals[all_animals.id==animal].test5.values=='bundled':
#             switch_in_channel_order = {0:0, 1:3, 2:1, 3:2}
#             binned_distances_transposed['middleDendrite'] = binned_distances_transposed.\
#                                                             apply(middleDendrite, axis=1)
#
#             # deal with switched channel order
#             if animal.split('/')[-1].split('_')[1][:3] == '072':
#                 print(animal.split('/')[-1].split('_')[1] + ' changed channel order')
#                 binned_distances_transposed['middleDendrite'] = binned_distances_transposed.\
#                                                                 middleDendrite.\
#                                                                 apply(lambda x: switch_in_channel_order[x])
#             elif animal.split('/')[-1].split('_')[1][:2] == '05' and animal.split('/')[-1].split('_')[1][4:6] == '18':
#                 print(animal.split('/')[-1].split('_')[1] + ' changed channel order')
#                 binned_distances_transposed['middleDendrite'] = binned_distances_transposed.\
#                                                                 middleDendrite.\
#                                                                 apply(lambda x: switch_in_channel_order[x])
#             middle_dendrite_df[animal.split('/')[-1]] = binned_distances_transposed['middleDendrite']
#         else:
#             print(all_animals[all_animals.id==animal].id.values + 'is defasciculated')
#
#
#     # max pairwise plots
#     getMaxPairwisePlot(max_pairwise_df, timepoint=timepoint, genotype=genotype)
#     defascThicknessPlot(animal=animal, max_pairwise_df=max_pairwise_df, genotype=genotype, timepoint=timepoint)
#
#     max_pairwise_df.to_csv('./SADA csv files binned/' + genotype + '/' + \
#                        genotype + '_' + timepoint + '_maxpairwise_pop.csv')
#     middle_dendrite_df.to_csv('./SADA csv files binned/' + genotype + '/' + \
#                        genotype + '_' + timepoint + '_middle_dendr_pop.csv')
#     return middle_dendrite_df
#
#
# def defascThicknessPlot(animal, max_pairwise_df, genotype, timepoint):
#     animal = animal.lower()
#     if '60x' in animal:
#         df_pos = max_pairwise_df/2/9.26
#         df_neg = -max_pairwise_df/2/9.26
#     elif '40x' in animal:
#         df_pos = max_pairwise_df/2/6.646
#         df_neg = -max_pairwise_df/2/6.646
#
#     for i in max_pairwise_df.columns:
#         plt.fill_between(df_pos.index, df_pos.ix[:, i], df_neg.ix[:, i],
#                          color='cornflowerblue',
#                          alpha = 0.1,
#                         )
#     plt.ylim([-3, 3])
#     plt.xlim([0, 100])
#     plt.axhline(y=-1, color='black')
#     plt.axhline(y=1, color='black')
#     plt.grid(color='b', axis='y', alpha=0.5)
#     plt.axis('off')
#     plt.savefig('./SADA csv files binned/' + genotype + '/' + \
#                        genotype + '_' + timepoint + '_defascThicknessPlot.svg')
#     plt.close()
#
# # heatmap
# def getHeatmap(middle_dendrite_df, genotype, timepoint):
#     from matplotlib.colors import LinearSegmentedColormap
#     vmax = 3.0
#     cmap = LinearSegmentedColormap.from_list('mycmap', [(0 / vmax, 'white'),
#                                                     (1 / vmax, 'yellow'),
#                                                     (2 / vmax, 'red'),
#                                                     (3 / vmax, 'blue')])
#     fig, ax = plt.subplots()
#     plt.pcolor(middle_dendrite_df.T, cmap=cmap, vmin=0, vmax=vmax)
#     ax.set_yticks(np.arange(middle_dendrite_df.shape[1]) + 0.5, minor=False)
#     ax.invert_yaxis()
#     ax.set_yticklabels(middle_dendrite_df.columns, minor = False)
#     ax.tick_params('off')
#     plt.title(genotype + '_' + timepoint + ' n=' + str(middle_dendrite_df.shape[1]))
#     plt.savefig('./SADA csv files binned/' + genotype + '/' + \
#                        genotype + '_' + timepoint + '_heatmap.svg')
#     plt.close()
#
# # make summary plot
# def summaryPlot(middle_dendrite_df, genotype, timepoint):
#     summary_plot_df = pd.DataFrame()
#     for i in middle_dendrite_df.T.columns[::-1]:
#         summary_plot_df = pd.DataFrame(middle_dendrite_df.T[i].value_counts()).join(summary_plot_df, how='outer')
#
#     (summary_plot_df / summary_plot_df.sum()).T.\
#     replace(np.nan, 0.).\
#     rolling(5, center=True).mean().plot(color=['orange','r','b'])
#     plt.legend('')
#     plt.ylim([0.0,1.0])
#     plt.xlim([0,100])
#     plt.tick_params('off')
#     plt.savefig('./SADA csv files binned/' + genotype + '/' + \
#                        genotype + '_' + timepoint + '_summaryplot.svg')
#     plt.close()
#
#     return summary_plot_df
#
# # chi-squared test + color bar
# def chiSquareTest(summary_plot_df, genotype, timepoint):
#     chi_sq_df = summary_plot_df.T
#     chi_sq_df['total'] = chi_sq_df.sum(axis=1)
#     chi_sq_df['expected_values'] = chi_sq_df.total / 3.
#     try:
#         chi_sq_df.columns=['zeroes', 'one','two','three','total','expected_values']
#     except ValueError:
#         chi_sq_df.columns=['one','two','three','total','expected_values']
#     chi_sq_df = chi_sq_df.replace(np.nan, 0.)
#
#     from scipy.stats import chisquare
#     def getChiSquare(df):
#         return chisquare([df['one'], df['two'], df['three']], df.expected_values)[1]
#
#     chi_sq_df['chi_sq_p_vals'] = chi_sq_df.apply(getChiSquare, axis=1)
#     chi_sq_df.rolling(5, center=True).mean().to_csv('./SADA csv files binned/' + genotype + '/' + \
#                        genotype + '_' + timepoint + '_chisq.csv')
#
#     plt.pcolor(pd.DataFrame(chi_sq_df.chi_sq_p_vals.\
#                             rolling(5, center=True).mean().dropna()),
#                norm=LogNorm(vmin=0.000001, vmax=1.0),
#                cmap='Greens_r')
#     plt.colorbar()
#     plt.savefig('./SADA csv files binned/' + genotype + '/' + \
#                        genotype + '_' + timepoint + '_chi_sq_bar.svg')
#     plt.close()
#
# # other fns
# def middleDendrite(df):
#     if df.RG_binned == df.BR_binned == df.GB_binned:
#         return 0
#     elif df.RG_binned == df.max_pairwise:
#         return 1 # blue
#     elif df.BR_binned == df.max_pairwise:
#         return 2 # yellow
#     elif df.GB_binned == df.max_pairwise:
#         return 3 # red
#     return 0
#
# def middledendrite(binned_distances_transposed, file_name):
#     """
#     looking for middle dendrite points as defined by the point across the longest pairwise distance
#     input: binned_distances_transposed
#     returns: mid_dendrite_col
#     """
#
#     for row in binned_distances_transposed:
#         if row[0] == row[1] == row[2]:
#             mid_dendrite = 0
#         elif row[0] == max(row):
#             mid_dendrite = 1
#         elif row[1] == max(row):
#             mid_dendrite = 2
#         elif row[2] == max(row):
#             mid_dendrite = 3
#         else:
#             mid_dendrite = 0
#
#         # convert WT values that start with 072 to the right color order
#         if file_name[3:6] == '072':
#             mid_dendrite = mydict[mid_dendrite]
#
#         # convert WT values that start with 072 to the right color order
#         if file_name[3:5] == '05' and file_name[7:9] == '18':
#             mid_dendrite = mydict[mid_dendrite]
#         mid_dendrite_col.append(mid_dendrite)
#
#
#     return mid_dendrite_col
#
# def getMaxPairwisePlot(max_pairwise_df, timepoint, genotype):
#     plt.figure()
#     max_pairwise_df.rolling(5, center=True).mean().plot(color='cornflowerblue')
#     plt.legend('')
#
#     if timepoint == '48h' or timepoint == '24h':
#         plt.ylim([0.0, float(9*5)]) # 5 micron y-range at 60x objective
#         plt.yticks(np.arange(0, float(9*5)+1, 9))
#
#     elif timepoint == '72h' and genotype == 'WT':
#         plt.ylim([0.0, float(6*5)]) # 5 micron y-range at 40x objective
#         plt.yticks(np.arange(0, float(6*5)+1, 6))
#
#     elif timepoint == '72h':
#         plt.ylim([0.0, float(9*5)]) # 5 micron y-range at 60x objective
#         plt.yticks(np.arange(0, float(9*5)+1, 9))
#
#     else:
#         print ('warning, y axis numbers for maxpairwise dist plot incorrect')
#     plt.xlabel('distance along dendrite, 100 bins')
#     plt.ylabel('maximum pairwise distance, 5 microns')
#     plt.title('maxpairwise distance plot for ' + genotype + '_' + timepoint)
#
#     plt.savefig('./SADA csv files binned/' + genotype + '/' +                 genotype + '_' + timepoint + '_maxpairwise_pop_plot.svg')
#     plt.close()
#
# def binned_dist(RG_dist, BR_dist, GB_dist, bins=100):
#     pixels = len(RG_dist)
#     bin_size = pixels/bins
#     n=0
#     bin_index = []
#     while n <= pixels:
#         bin_index.append(round(n))
#         n += bin_size
#
#     RG_binned = []
#     BR_binned = []
#     GB_binned = []
#
#     n_bins = 0
#     while n_bins < (len(bin_index)-1):
#         RG_bin = sum(RG_dist[bin_index[n_bins] : bin_index[n_bins + 1]]) / (-bin_index[n_bins] + bin_index[n_bins + 1])
#         RG_binned.append(RG_bin)
#         BR_bin = sum(BR_dist[bin_index[n_bins] : bin_index[n_bins + 1]]) / (-bin_index[n_bins] + bin_index[n_bins + 1])
#         BR_binned.append(BR_bin)
#         GB_bin = sum(GB_dist[bin_index[n_bins] : bin_index[n_bins + 1]]) / (-bin_index[n_bins] + bin_index[n_bins + 1])
#         GB_binned.append(GB_bin)
#         n_bins += 1
#
#     binned_distances = RG_binned, BR_binned, GB_binned
#     binned_distances_transposed = np.transpose(binned_distances)
#
#     return binned_distances_transposed
#
# def normalization(RG_dist, BR_dist, GB_dist, animal, timepoint):
#     normalization_factor_microns = int(animal.split('/')[-1].split('_')[0])
#
#     # adjust normalization factor according to image magnification (40x/60x/100x)
#     animal_lower = animal.lower()
#     if '100x' in animal_lower:
#         normalization_factor_pixels = 15 * normalization_factor_microns
#     elif '40x' in animal_lower:
#         normalization_factor_pixels = 6 * normalization_factor_microns
#     elif '60x' in animal_lower and timepoint == '48h': # 60x
#         normalization_factor_pixels = int(9 * normalization_factor_microns * 0.9) # 90% of the anatomical distance
#     elif '60x' in animal_lower and timepoint == '24h':
#         normalization_factor_pixels = int(9 * normalization_factor_microns * 0.8) # 80% of the anatomical distance
#     elif '60x' in animal_lower and timepoint == '72h':
#         normalization_factor_pixels = int(9 * normalization_factor_microns * 1.0) # 100% of the anatomical distance
#     zeros = [0] * (normalization_factor_pixels)
#     RG_dist_de = [x_rg + y_rg for x_rg, y_rg in zip_longest(zeros, RG_dist, fillvalue=0)]
#     BR_dist_de = [x_br + y_br for x_br, y_br in zip_longest(zeros, BR_dist, fillvalue=0)]
#     GB_dist_de = [x_gb + y_gb for x_gb, y_gb in zip_longest(zeros, GB_dist, fillvalue=0)]
#
#     RG_dist_de = RG_dist_de[:normalization_factor_pixels]
#     BR_dist_de = BR_dist_de[:normalization_factor_pixels]
#     GB_dist_de = GB_dist_de[:normalization_factor_pixels]
#
#     normalized_pairwise = RG_dist_de, BR_dist_de, GB_dist_de
#     return normalized_pairwise
#
# # Final
# def applyAll(genotype, timepoint):
#     middle_dendrite_df = maxpairwiseAndMiddleDendrite(genotype, timepoint)
#     getHeatmap(middle_dendrite_df, genotype, timepoint)
#     summary_plot_df = summaryPlot(middle_dendrite_df, genotype, timepoint)
#     chiSquareTest(summary_plot_df, genotype, timepoint)
